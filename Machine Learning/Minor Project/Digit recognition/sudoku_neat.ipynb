# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
sud = cv2.imread("sudoku.png")

# %%
sud.astype("float64").dtype
# Out:
# dtype('float64')

# %%
sud = cv2.resize(sud,(256,256))

# %%
plt.imshow(sud)
